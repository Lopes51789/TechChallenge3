# %% [markdown]
# # Tech Challenge 3

# %% [markdown]
# ## Parte 0: Configuração inicial

# %%
# %pip install -r requirements.txt --user

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import os
import sys

# %%
"""
os.environ["HADOOP_HOME"] = "C:\\hadoop"
sys.path.append("C:\\hadoop\\bin")
os.environ["PATH"] += os.pathsep + "C:\\hadoop\\bin"
"""

# %%
spark = (
    SparkSession
    .builder
    .master("local[*]")
    .getOrCreate()
)

spark.version

# %%
df23_24 = spark.read.csv("data\\State_of_data_BR_2023_Kaggle - df_survey_2023.csv", sep=",", inferSchema=True, header=True)
df24_25 = spark.read.csv("data\\Final Dataset - State of Data 2024 - Kaggle - df_survey_2024.csv", sep=",", inferSchema=True, header=True)
df25_26 = spark.read.csv("data\\Final Dataset - State of Data 2025-2026 - Kaggle.csv", sep=",", inferSchema=True, header=True)

# %% [markdown]
# ## Parte 1: Exploração

# %% [markdown]
# ### 2023 - 2024

# %%
#Schema do DataFrame do ano de 2023 até 2024
df23_24.printSchema()

# %% [markdown]
# ### 2024 - 2025

# %%
#Schema do DataFrame do ano de 2024 até 2025
df24_25.printSchema()

# %% [markdown]
# ### 2025 - 2026

# %%
#Schema do DataFrame do ano de 2025 até 2026
df25_26.printSchema()

# %% [markdown]
# ## Parte 2: Respondendo Perguntas

# %% [markdown]
# ### Como está estruturado o mercado brasileiro de dados?

# %% [markdown]
# ### Quais Perfis profissionais são mais valorizados pelo mercado?

# %% [markdown]
# ### Qual é o cenário de diversidade de genêro nas carreiras de dados?

# %% [markdown]
# ### Quais tecnologias apresentam maior adoção entre profissionais?

# %% [markdown]
# ### Qual é o índice de adoção de IA e seu impacto?

# %% [markdown]
# ### Existem diferenças relevantes entre regiões, senioridades ou modelos de trabalho?

# %% [markdown]
# ### Quais oportunidades e desafios podem ser identificados para empresas que desejam investir em Dados e Inteligência Artificial?

# %% [markdown]
# ## Parte 3: Perguntas Pessoasis

# %% [markdown]
# ### Qual é a tendência de IA no mercado de trabalho?
